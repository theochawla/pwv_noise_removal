# %%
#import os
#os.environ['PYSYN_CDBS'] = "C:/Users/tchawla/research/HST_data/grp/redcat/trds"
#env_var = os.environ['PYSYN_CDBS']
#env_var
import numpy as np
from astropy.io import ascii
from pylab import *
from astropy.table import Table, vstack
import pandas as pd
from expecto import get_spectrum
from scipy.interpolate import RegularGridInterpolator as rgi
from itertools import product
# %run Interpolate_final.ipynb
# %run GetSpectra_final.ipynb
# %run Binning_final.ipynb
# %run AddNoise_final.ipynb
#%set_env PYSYN_CDBS = C:/Users/tchawla/research/HST_data/grp/redcat/trds

# %%
#env_var

# %%
#PYSYN_CDBS

# %%
water_array = [1.0, 1.5, 2.5, 3.5, 5.0]

'''
reads in .dat files. col1 is wavelength, col2 is transmission. Files are labeled with water content level in mm 
water content levels are listed in the array above. resolution is 200,000.
'''

d = {}
i=0
for n in water_array:
    water_content = str(water_array[i])
    d["data"+water_content] = ascii.read("transmission{0}_hi_res.dat".format(water_content))
    d["data"+water_content+"_pd"] = d["data"+water_content].to_pandas()
    #print(d["data"+water_content+"_pd"])
    i+=1

# %%
'''
for loop creates transmission values in shape necessary for interpolation function
'''
water_array = [1.0, 1.5, 2.5, 3.5, 5.0]

flux_array = []
i=0
for n in water_array:
    water_array_i = str(water_array[i])
    d["flux"+water_array_i] = np.array(d["data"+water_array_i+"_pd"]["col2"])
    flux_array.append(d["flux"+water_array_i])
    i+=1

# %%
pwv = np.load("pwv_target.npy")

# %%
spectrum_test10 = spectrum(4000, 10)
spectrum_test5 = spectrum(4000, 5)
spectrum_test1 = spectrum(4000, -1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 spectrum_test10 = spectrum(4000, 10)
# ----> 2 spectrum_test5 = spectrum(4000, 5)
#       3 spectrum_test1 = spectrum(4000, -1)
#
# File /var/folders/h_/vkbcrvtd39b6btnqzmk30tqm0000gr/T/ipykernel_43157/3575753551.py:6, in spectrum(T, mag, surf_g)
#       5 def spectrum(T, mag, surf_g=4.5):
# ----> 6     spectrum = get_spectrum(T_eff=T, log_g=surf_g, cache=False)
#       8     wave, flux = normalize_expecto_to_magnitude(spectrum.wavelength, spectrum.flux, mag)
#      10     return wave, flux
#
# File ~/anaconda3/lib/python3.10/site-packages/expecto/core.py:164, in get_spectrum(T_eff, log_g, Z, alpha, cache, vacuum)
#     129 """
#     130 Download a PHOENIX model atmosphere spectrum for a star with given
#     131 properties.
#    (...)
#     159 :py:class:`~astropy.utils.data.Conf`.
#     160 """
#     161 url = get_url(
#     162     T_eff=T_eff, log_g=log_g, Z=Z, alpha=alpha
#     163 )
# --> 164 with fits.open(url, cache=cache) as fits_file:
#     165     with warnings.catch_warnings():
#     166         warnings.simplefilter("ignore", UnitsWarning)
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:175, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     172 if not name:
#     173     raise ValueError(f'Empty filename: {name!r}')
# --> 175 return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     176                         lazy_load_hdus, ignore_missing_simple, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:410, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     398 @classmethod
#     399 def fromfile(cls, fileobj, mode=None, memmap=None,
#     400              save_backup=False, cache=True, lazy_load_hdus=True,
#     401              ignore_missing_simple=False, **kwargs):
#     402     """
#     403     Creates an `HDUList` instance from a file-like object.
#     404
#    (...)
#     407     documentation for details of the parameters accepted by this method).
#     408     """
# --> 410     return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     411                          save_backup=save_backup, cache=cache,
#     412                          ignore_missing_simple=ignore_missing_simple,
#     413                          lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:1060, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#    1057 if fileobj is not None:
#    1058     if not isinstance(fileobj, _File):
#    1059         # instantiate a FITS file object (ffo)
# -> 1060         fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1061     # The Astropy mode is determined by the _File initializer if the
#    1062     # supplied mode was None
#    1063     mode = fileobj.mode
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/io/fits/file.py:151, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache)
#     148 # Handle raw URLs
#     149 if (isinstance(fileobj, (str, bytes)) and
#     150         mode not in ('ostream', 'append', 'update') and _is_url(fileobj)):
# --> 151     self.name = download_file(fileobj, cache=cache)
#     152 # Handle responses from URL requests that have already been opened
#     153 elif isinstance(fileobj, http.client.HTTPResponse):
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/utils/data.py:1363, in download_file(remote_url, cache, show_progress, timeout, sources, pkgname, http_headers, ssl_context, allow_insecure)
#    1361 for source_url in sources:
#    1362     try:
# -> 1363         f_name = _download_file_from_source(
#    1364                 source_url,
#    1365                 timeout=timeout,
#    1366                 show_progress=show_progress,
#    1367                 cache=cache,
#    1368                 remote_url=remote_url,
#    1369                 pkgname=pkgname,
#    1370                 http_headers=http_headers,
#    1371                 ssl_context=ssl_context,
#    1372                 allow_insecure=allow_insecure)
#    1373         # Success!
#    1374         break
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/utils/data.py:1152, in _download_file_from_source(source_url, show_progress, timeout, remote_url, cache, pkgname, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1150 if ftp_tls is None and urllib.parse.urlparse(remote_url).scheme == "ftp":
#    1151     try:
# -> 1152         return _download_file_from_source(source_url,
#    1153                                           show_progress=show_progress,
#    1154                                           timeout=timeout,
#    1155                                           remote_url=remote_url,
#    1156                                           cache=cache,
#    1157                                           pkgname=pkgname,
#    1158                                           http_headers=http_headers,
#    1159                                           ftp_tls=False)
#    1160     except urllib.error.URLError as e:
#    1161         # e.reason might not be a string, e.g. socket.gaierror
#    1162         if str(e.reason).startswith("ftp error: error_perm"):
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/utils/data.py:1167, in _download_file_from_source(source_url, show_progress, timeout, remote_url, cache, pkgname, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1164         else:
#    1165             raise
# -> 1167 with _try_url_open(source_url, timeout=timeout, http_headers=http_headers,
#    1168                    ftp_tls=ftp_tls, ssl_context=ssl_context,
#    1169                    allow_insecure=allow_insecure) as remote:
#    1170     info = remote.info()
#    1171     try:
#
# File ~/anaconda3/lib/python3.10/site-packages/astropy/utils/data.py:1104, in _try_url_open(source_url, timeout, http_headers, ftp_tls, ssl_context, allow_insecure)
#    1101 req = urllib.request.Request(source_url, headers=http_headers)
#    1103 try:
# -> 1104     return urlopener.open(req, timeout=timeout)
#    1105 except urllib.error.URLError as exc:
#    1106     reason = exc.reason
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:1565, in FTPHandler.ftp_open(self, req)
#    1563     dirs = dirs[1:]
#    1564 try:
# -> 1565     fw = self.connect_ftp(user, passwd, host, port, dirs, req.timeout)
#    1566     type = file and 'I' or 'D'
#    1567     for attr in attrs:
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:1585, in FTPHandler.connect_ftp(self, user, passwd, host, port, dirs, timeout)
#    1584 def connect_ftp(self, user, passwd, host, port, dirs, timeout):
# -> 1585     return ftpwrapper(user, passwd, host, port, dirs, timeout,
#    1586                       persistent=False)
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:2406, in ftpwrapper.__init__(self, user, passwd, host, port, dirs, timeout, persistent)
#    2404 self.keepalive = persistent
#    2405 try:
# -> 2406     self.init()
#    2407 except:
#    2408     self.close()
#
# File ~/anaconda3/lib/python3.10/urllib/request.py:2418, in ftpwrapper.init(self)
#    2416 self.ftp.login(self.user, self.passwd)
#    2417 _target = '/'.join(self.dirs)
# -> 2418 self.ftp.cwd(_target)
#
# File ~/anaconda3/lib/python3.10/ftplib.py:625, in FTP.cwd(self, dirname)
#     623     dirname = '.'  # does nothing, but could return error
#     624 cmd = 'CWD ' + dirname
# --> 625 return self.voidcmd(cmd)
#
# File ~/anaconda3/lib/python3.10/ftplib.py:286, in FTP.voidcmd(self, cmd)
#     284 """Send a command and expect a response beginning with '2'."""
#     285 self.putcmd(cmd)
# --> 286 return self.voidresp()
#
# File ~/anaconda3/lib/python3.10/ftplib.py:259, in FTP.voidresp(self)
#     257 def voidresp(self):
#     258     """Expect a response beginning with '2'."""
# --> 259     resp = self.getresp()
#     260     if resp[:1] != '2':
#     261         raise error_reply(resp)
#
# File ~/anaconda3/lib/python3.10/ftplib.py:244, in FTP.getresp(self)
#     243 def getresp(self):
# --> 244     resp = self.getmultiline()
#     245     if self.debugging:
#     246         print('*resp*', self.sanitize(resp))
#
# File ~/anaconda3/lib/python3.10/ftplib.py:230, in FTP.getmultiline(self)
#     229 def getmultiline(self):
# --> 230     line = self.getline()
#     231     if line[3:4] == '-':
#     232         code = line[:3]
#
# File ~/anaconda3/lib/python3.10/ftplib.py:212, in FTP.getline(self)
#     211 def getline(self):
# --> 212     line = self.file.readline(self.maxline + 1)
#     213     if len(line) > self.maxline:
#     214         raise Error("got more than %d bytes" % self.maxline)
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
spectrum_test10_hot = spectrum(7000, 10)
spectrum_test5_hot = spectrum(7000, 5)
spectrum_test1_hot = spectrum(7000, -1)

# %%
print(np.max(spectrum_test10[1]))
print(np.max(spectrum_test5[1]))
print(np.max(spectrum_test1[1]))

# %%
plt.plot(spectrum_test10[0], spectrum_test10[1])

# %%
print(np.max(spectrum_test10_hot[1]))
print(np.max(spectrum_test5_hot[1]))
print(np.max(spectrum_test1_hot[1]))

# %%
plt.plot(spectrum_test10_hot[0], spectrum_test10_hot[1])

# %%
print(len(spectrum_test[0]))
print(len(spectrum_test[1]))

# %%
spec_range = spec_wave_range(spectrum_test, 1.8, 1.95)
spec_range

# %%
flux_norm = diff_spec_v2(4000, 6000, pwv, pwv, 1.8, 1.95, 8, 9)

# %%
plt.plot(flux_norm[0]*10**6)

# %%
timestamps = np.linspace(0,10,1000) #time in hours
t, target_star_pwv, target_star_phase, target_star_mean = power_spectrum(12000, 1, 24000, timestamps, mean = 2)
t1, comparison_star_pwv, _, _ = power_spectrum(12000, 1, 24000, timestamps, mean = target_star_mean, target = False, phase = target_star_phase, separation = 25)

plt.plot(t, target_star_pwv)
plt.plot(t, comparison_star_pwv)
plt.show()

# %%
flux_norm = diff_spec_v2(4000, 6000, target_star_pwv, comparison_star_pwv, 1.8, 1.95, 5, 6)

# %%
plt.plot(flux_norm[0]*10**6)

plt.title("Time Series at 1.8 microns")
plt.ylabel("Change in flux, ppm")
plt.xlabel("time")

# %%
def photon_noise(flux, bin_size, mirror_diameter = 1, exp_time = 60, throughput = .4):
    
    mirror_area = np.pi*((mirror_diameter/2)**2) - np.pi*((.25)**2)
    #print("mirror area:"+str(mirror_area))
    
    #bin_size_array = [bin_array[1]-bin_array[0]]
    '''
    i=0
    for n in bin_array:
        if i == len(bin_array)-1:
            break
        bin_size2 = bin_array[i+1] - bin_array[i]
        bin_size_array.append(bin_size2)
        j+=1
    '''
    num_photons = flux*mirror_area*exp_time*throughput*bin_size
    print("num photons:"+str(num_photons))
    noise_std_dev = 1/(num_photons**(1/2))
    print("noise std dev:"+str(noise_std_dev))
    
    photon_noise_gaussian = np.random.normal(1, noise_std_dev, len(flux))
    
    return photon_noise_gaussian

# %%
flux_array_adjusted = np.array([500*10**4, 2*10**4, .2*10**4])
flux_array = np.array([500, 2, .2])
photon_noise(flux_array, 180)

# %%
#cold_star = spectrum(4000, 5)

# %%
#cold_star

# %%
res_bin_timestamp(cold_star[1], cold_star[0], 200, 18000, 19500)

# %%
planet_atm = ascii.read("planet_atm_spec.dat")
planet_atm
# Out:
# <Table length=278>
#     col1        col2     col3    col4     col5    col6
#   float64     float64  float64 float64  float64 float64
# ------------ --------- ------- -------- ------- -------
#          0.6 781.01897  228.61 985626.0 781.019 781.019
#        0.603 748.76297  225.99 985626.0 748.763 748.763
#     0.606015 729.26896 222.672 985626.0 729.269 729.269
#  0.609045075 712.78296 219.442 985626.0 712.783 712.783
# 0.6120903004 707.96196 216.296 985626.0 707.962 707.962
# 0.6151507519 726.21895  213.23 985626.0 726.219 726.219
#          ...       ...     ...      ...     ...     ...
#  2.318216467 2399.3479 93.9855 985626.0 2399.35  2399.6
#  2.329807549 2346.2998 94.3186 985626.0  2346.3 2346.46
#  2.341456587 2340.9976 94.6549 985626.0  2341.0 2341.22
#   2.35316387 2346.2485 94.9958 985626.0 2346.25  2346.5
#  2.364929689 2266.9127 95.3448 985626.0 2266.91 2267.28
#  2.376754338 2382.7421 95.6919 985626.0 2382.74 2382.93
#  2.388638109 2216.8598 96.0544 985626.0 2216.86 2217.22

# %%
# %run Interpolate_final.ipynb
# %run Binning_final.ipynb
# %run AddNoise_final.ipynb
# %run GetSpectra_final.ipynb

# %%
target_spec, ref_spec = diff_spec_v2_pt1(4000, 6000, 6, 7)

# %%
ref_spec
# Out:
# (array([  500.  ,   500.1 ,   500.2 , ..., 54999.25, 54999.5 , 54999.75]),
#  array([4.96119691e-29, 5.03567076e-29, 5.11123156e-29, ...,
#         7.24297854e-03, 7.24032410e-03, 7.24250824e-03]))

# %%
'''
function that takes in stellar spectrum, wave range, and res. Output is timeseries of flux based on pwv variability,
one timeseries for each wavelength. 
'''


def binned_flux_pwv_v2(spectrum, pwv_input, wave_in, wave_out, res):
    stellar = spec_wave_range(spectrum, wave_in, wave_out)
    stellar_wave = stellar[0]
    stellar_flux = stellar[1]
    #pwv = np.load("pwv_target.npy")
    
    
    transmission_array = []
    
    i=0
    for n in stellar_wave:
        str_value = str(stellar_wave[i])
        value = stellar_wave[i]/10
        stellar_flux_value = stellar_flux[i]
        transmission  = interpolate_water(pwv_input, value)
        flux = stellar_flux_value*transmission
        d[str_value+"_trans_array"] = np.array(flux)
    
        transmission_array.append(d[str_value+"_trans_array"])
        i+=1
        
    transmission_array = np.array(transmission_array)
    
    #time_array = np.arange(0, 627, 1)
    
    transmission_array_binned = []
    #wave_in_converted = wave_in*1000
    #wave_out_converted = wave_out*1000
    wave_in_converted = wave_in*100
    wave_out_converted = wave_out*100
    
    print(stellar_wave)
    j=0
    for n in time_array:
        
        bin_1 = res_bin_timestamp(transmission_array[:,j], stellar_wave, res, wave_in_converted, wave_out_converted)
        transmission_array_binned.append(bin_1)
        j+=1
    
    return(transmission_array_binned)

# %%
#target_binned = binned_flux_pwv_v2(target_spec, target_star_pwv, 1.8, 1.95, 200)

# %%
spec_wave_range_test = spec_wave_range(target_spec, 1.8, 1.95)

# %%
spec_wave_range_test
# Out:
# (array([18000.  , 18000.03, 18000.06, ..., 19499.91, 19499.94, 19499.97]),
#  array([0.60714067, 0.60113144, 0.60075032, ..., 0.51470297, 0.51478081,
#         0.51537777]))

# %%
stellar_wave = spec_wave_range_test[0]
stellar_flux = spec_wave_range_test[1]
transmission_array = []
    
i=0
for n in stellar_wave:
    str_value = str(stellar_wave[i])
    value = stellar_wave[i]/10
    stellar_flux_value = stellar_flux[i]
    transmission  = interpolate_water(target_star_pwv, value)
    flux = stellar_flux_value*transmission
    d[str_value+"_trans_array"] = np.array(flux)
    
    transmission_array.append(d[str_value+"_trans_array"])
    i+=1
        
transmission_array = np.array(transmission_array)

# %%
#transmission_array

# %%
'''
tweaked binning function that allows binning at every point in the pwv timeseries
'''

def res_bin_timestamp(flux, wavelength, res, wave_in, wave_fin, spectrum_type="stellar"):
    #print(wavelength)
    #print
    print(flux)
    wave_in = wavelength[0]
    wave_fin = wavelength[-1]
    wave_array = [wave_in]
    n=wave_array[0]
    i=0
    #print(wave_in)
    #print(wave_fin)
    while wave_in <= n <= wave_fin:
        if wave_array[i] >= wave_fin:
            break
        bin_size = wave_array[i]/res
        if wave_array[i]+bin_size >= wave_fin:
            break
        wave_array.append(wave_array[i]+bin_size)
        n=wave_array[i]
        i+=1
    #print(wave_array)
    
    
        
    if spectrum_type == "stellar":
        
        wave_in_index = 0
        wave_out_index = -1
        
        '''
        use this section if using binning function individually and need to specify wave range
        wave_in_index = np.where(wavelength == wave_in*10)[0]
        print(wave_in_index)
        wave_out_index = np.where(wavelength == wave_fin*10)[0]
        print(wave_out_index)
        '''

        wavelength_range = wavelength[wave_in_index:wave_out_index]
        #print(wavelength_range)
        #finds step size of stellar spectrum
        
        high_res_step = [wavelength_range[1]-wavelength_range[0]]
        j=0
        for n in wavelength:
            if j == len(wavelength_range)-1:
                break
            bin_size2 = wavelength_range[j+1] - wavelength_range[j]
            high_res_step.append(bin_size2)
            j+=1
        
        #flux must be multiplied by fractional step size in order to scale it for binning
        #flux = (spectrum.flux.value)*high_res_step
        flux_new = (flux[wave_in_index:wave_out_index])*high_res_step
        #print(high_res_step)
        #print(len(flux_new))
        #print(len(wavelength_range))
        print(len(flux_new))
        
        
    elif spectrum_type == "earth":
        wavelength = spectrum["col1"]
        flux = spectrum["col2"]
    
    #plt.hist(wavelength_range, bins=wave_array, weights=flux_new)
    #plt.show()
    return np.histogram(wavelength_range, bins=wave_array, weights=flux_new)

# %%
#transmission_array_np = np.array(transmission_array)
binning_fix = res_bin_timestamp(transmission_array_np[:,0], spec_wave_range_test[0], 200, 18000, 19500)
# Out:
# [0.06381995 0.08870825 0.11699398 ... 0.04247021 0.04444222 0.04646162]
# 49999

# %%
binning_fix
# Out:
# (array([29.01719112, 25.48125519, 17.37855607,  9.05828656,  6.23029781,
#          5.26645077,  8.19615132,  4.31013695,  8.26221496, 12.99508845,
#          9.55767533,  8.59457496, 10.05860426, 17.16998959, 18.99762041,
#         23.7851199 ]),
#  array([18000.        , 18090.        , 18180.45      , 18271.35225   ,
#         18362.70901125, 18454.52255631, 18546.79516909, 18639.52914493,
#         18732.72679066, 18826.39042461, 18920.52237673, 19015.12498862,
#         19110.20061356, 19205.75161663, 19301.78037471, 19398.28927659,
#         19495.28072297]))

# %%
transmission_array_np = np.array(transmission_array)
#len(transmission_array[:,0])
#len(transmission_array[2])
#len(target_star_pwv)
len(transmission_array[0])
# Out:
# 1000

# %%
#target_spec[0]
diff2 = diff_spec_v2_pt2(target_spec, ref_spec, target_star_pwv, comparison_star_pwv, 1.65, 2.1)

'''
wave in / wave out indexing is having trouble in the timestamp binning function. 
Maybe I don't need indexing? Depending on wave range, maybe I can just take the first and last wave values?
The binning means there is no 2.1 micron value, just 2.099996

'''
# Out:
# "\nwave in / wave out indexing is having trouble in the timestamp binning function. \nMaybe I don't need indexing? Depending on wave range, maybe I can just take the first and last wave values?\nThe binning means there is no 2.1 micron value, just 2.099996\n\n"

# %%
#test = np.where()

# %%
len(diff2)
# Out:
# 48

# %%
#plt.plot(diff2[0])

# %%
diff_spec = diff_spec_v2_pt3(diff2)

# %%
len(diff2)
# Out:
# 48

# %%
#len(diff_spec)
#diff_spec[0]

# %%
plt.plot(diff_spec[40]*10**6)

# %%
bin_array2 = bin_array(1.65, 2.1, 200)

# %%
print(bin_array2[40])
# Out:
# 2.0143104902032185

# %%
#print(diff_spec)
